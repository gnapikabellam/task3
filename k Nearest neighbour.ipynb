# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('data.csv')
dataset

# %% [markdown]
# summarization of data set

# %%
print(dataset.shape)
x=dataset.head()
x
# Out:
# (9568, 5)
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %% [markdown]
# segargate input and output

# %%
 x=dataset.iloc[:,0:-1]
 x
# Out:
#          AT      V       AP     RH
# 0      8.34  40.77  1010.84  90.01
# 1     23.64  58.49  1011.40  74.20
# 2     29.74  56.90  1007.15  41.91
# 3     19.07  49.69  1007.22  76.79
# 4     11.80  40.66  1017.13  97.20
# ...     ...    ...      ...    ...
# 9563  15.12  48.92  1011.80  72.93
# 9564  33.41  77.95  1010.30  59.72
# 9565  15.99  43.34  1014.20  78.66
# 9566  17.65  59.87  1018.58  94.65
# 9567  23.68  51.30  1011.86  71.24
#
# [9568 rows x 4 columns]

# %%
y=dataset.iloc[:,4:]
y
# Out:
#           PE
# 0     480.48
# 1     445.75
# 2     438.76
# 3     453.09
# 4     464.43
# ...      ...
# 9563  462.59
# 9564  432.90
# 9565  465.96
# 9566  450.93
# 9567  451.67
#
# [9568 rows x 1 columns]

# %% [markdown]
# train and test

# %%
# !pip install scikit_learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
x_train
# Out:
# array([[ 0.775606  ,  1.15139657, -1.01985265, -0.28944551],
#        [-0.3142815 , -0.75165848,  0.7084082 , -2.60221234],
#        [ 0.8226999 ,  0.23874697, -0.22167347, -2.04044265],
#        ...,
#        [ 0.52533554,  1.48441156, -0.23520193,  0.99489276],
#        [ 0.14723877,  0.30157999,  0.37019668,  0.30448396],
#        [-1.23597648, -1.02262587,  1.25292874,  1.28706774]])

# %% [markdown]
# finding k value

# %%
error=[] 
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
#calcularing errors for k values 
for i in range(1,40):
  model=KNeighborsClassifier(n_neighbors=i)
  model.fit(x_train,y_train)
  pred_i=model.predict(x_test)
  error.append(np.mean(pred_i!=y_test))
plt.figure(figsize=(12,6))
plt.plot(range(1,40),error,color='red',linestyle='dashed',marker='0',markerfacecolor='blue',markersize=10)
plt.title('error rate k value') 
plt.xlabel('k value')
plt.y_label('mean error')
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-fb8db8269927> in <module>
#       6 for i in range(1,40):
#       7   model=KNeighborsClassifier(n_neighbors=i)
# ----> 8   model.fit(x_train,y_train)
#       9   pred_i=model.predict(x_test)
#      10   error.append(np.mean(pred_i!=y_test))
#
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     196         self.weights = _check_weights(self.weights)
#     197
# --> 198         return self._fit(X, y)
#     199
#     200     def predict(self, X):
#
# ...
